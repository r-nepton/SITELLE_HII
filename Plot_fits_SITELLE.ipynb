# %%
# Import Libraries
import matplotlib 
matplotlib.use('TkAgg')
from matplotlib import rc
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
from matplotlib.patches import Rectangle

# %%
# Read WCS Values in Sexadecimal (x and y) and Degree (xx and yy)

x = np.loadtxt('x_wcs.txt', dtype='string')
xx = np.loadtxt('x_wcs_deg.txt')
print 'x[0]=',x[0]

y = np.loadtxt('y_wcs.txt', dtype='string')
yy = np.loadtxt('y_wcs_deg.txt')
print 'y[0]=',y[0]
# Out:
# x[0]= 01h37m08.528s
# y[0]= +15:43:27.91

# %%
# Set the Xaxis Ticks value 

# xxx is Defines with the deg+min/60 for each ticks wanted. 
# In this case it is 01h36m30s with step of 10s until 01h37m
xxx = [(1./24.)*360.+(36./(60.*24.))*360.+(30./(3600.*24.))*360.,\
       (1./24.)*360.+(36./(60.*24.))*360.+(40./(3600.*24.))*360.,\
       (1./24.)*360.+(36./(60.*24.))*360.+(50./(3600.*24.))*360.,\
       (1./24.)*360.+(37./(60.*24.))*360.+(00./(3600.*24.))*360.]
# xxxx is the Ticks value in String to inclue the h:m:s
xxxx=['36m30s','36m40s','36m50s','1h37m']
def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
# xxxxx is the Array Position of the defined xxx Values in the Data WCS 
xxxxx = np.zeros(4)
for i in range(0,4) : 
    xxxxx[i]=np.where(xx == find_nearest(xx,xxx[i]))[0]

# %%
# Set the Yaxis Ticks value 

# yyy is Defines with the deg+min/60 for each ticks wanted. 
# In this case it is +15d44m with step of 2m until +15d54m
yyy = [15+(44./(60)),\
       15+(46./(60)),\
       15+(48./(60)),\
       15+(50./(60)),\
       15+(52./(60)),\
       15+(54./(60))]

# yyyy is the Ticks value in String to inclue the $\degree$ symbol
yyyy=['+15$\degree$44','+15$\degree$46','+15$\degree$48','+15$\degree$50','+15$\degree$52','+15$\degree$54']

def find_nearest(array,value):
    idx = (np.abs(array-value)).argmin()
    return array[idx]
#yyyyy is the Array Position of the defined yyy Values in the Data WCS 
yyyyy = np.zeros(6)
for i in range(0,6) : 
    yyyyy[i]=np.where(yy == find_nearest(yy,yyy[i]))[0]

# %%
# Note for WCS overplot
# from astropy.wcs import WCS
# fits_file = 'NGC628_SN3.merged.tan.fits'
# hdu = fits.open(fits_file)[0]
# wcs = WCS(hdu.header)
            #Not convenient for the Font modification...

# %%
# Read Centroid position of the Ha Peak 
regxy = np.loadtxt('xy_region_centroid_GROW_XY2.txt')
regx = regxy[0:,0]
regy = regxy[0:,1]

# %%
# Read Fits Data and Data Header
hdu_list = fits.open('NGC628_SN3_6583_flux.fits')
hdu_list.info()

image_data = hdu_list[0].data
hdu_list.close()
# Out:
# WARNING: VerifyWarning: Invalid value for 'BLANK' keyword in header: 0.0 The 'BLANK' keyword must be an integer.  It will be ignored in the meantime. [astropy.io.fits.hdu.image]
# WARNING:astropy:VerifyWarning: Invalid value for 'BLANK' keyword in header: 0.0 The 'BLANK' keyword must be an integer.  It will be ignored in the meantime.
# WARNING: VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU. [astropy.io.fits.hdu.image]
# WARNING:astropy:VerifyWarning: Invalid 'BLANK' keyword in header.  The 'BLANK' keyword is only applicable to integer data, and will be ignored in this HDU.
# Filename: NGC628_SN3_6583_flux.fits
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU      71   (2048, 2064)   float32

# %%
# Plot the Data 
# %matplotlib nbagg

fig = plt.figure(figsize=(7.7,6))
plt.imshow(image_data, cmap='nipy_spectral')


#1
xlow1 = 362
xmax1 = 590
ylow1 = 550
ymax1 = 785

#2
xlow2 = 862
xmax2 = 1090
ylow2 = 840
ymax2 = 1075

#3
xlow3 = 1122
xmax3 = 1350
ylow3 = 865
ymax3 = 1100

#4
xlow4 = 1182
xmax4 = 1410
ylow4 = 574
ymax4 = 810

currentAxis = plt.gca()
currentAxis.add_patch(Rectangle((xlow1, ylow1), (xmax1-xlow1), (ymax1-ylow1), facecolor='None', edgecolor="white"))
currentAxis.add_patch(Rectangle((xlow2, ylow2), (xmax2-xlow2), (ymax2-ylow2), facecolor='None', edgecolor="white"))
currentAxis.add_patch(Rectangle((xlow3, ylow3), (xmax3-xlow3), (ymax3-ylow3), facecolor='None', edgecolor="white"))
currentAxis.add_patch(Rectangle((xlow4, ylow4), (xmax4-xlow4), (ymax4-ylow4), facecolor='None', edgecolor="white"))

# Plot the Color Scale
cbar=plt.colorbar(ticks=[-15,-15.5,-16,-16.5,-17,-17.5],pad=0.01)
cbar.set_label('$\mathrm{log\,\,Flux\,\,[\,erg\,\,s^{-1}\,\,cm^{-2}\,]}$', rotation=270, fontsize=16, labelpad=25)
plt.clim(-17.71,-14.95)

# Define the Data Plot Area
xlow = 0
xmax = 2048
ylow = 0
ymax = 2064
plt.xlim(xlow,xmax)
plt.ylim(ylow,ymax)

# Define the Scale of that_amount_of_pc Line Position
that_amount_of_pc = 1000
pc = str(that_amount_of_pc)+' pc' 
xlinelow = xlow + (xmax - xlow) * 0.1
xlinemax = xlow + (xmax - xlow) * 0.1 + 7.07/100 * that_amount_of_pc 
ylinelow = ylow + (ymax - ylow) * 0.9
ylinemax = ylow + (ymax - ylow) * 0.9

# Plot the Scale of that_amount_of_pc Line Position
plt.plot([xlinelow, xlinemax], [ylinelow, ylinemax], color='w', linewidth=1, marker = '|', markersize=3)
plt.annotate(pc, xy = [(xlinemax + xlinelow)/2, (ylinemax + ylinelow)/2 + 0.01*(ylinemax + ylinelow)], \
             ha = 'center', va = 'center', fontsize = 10, fontname = 'Times', color = 'w',fontweight='bold')

# Plot the Predefined Ticks

test = np.array(xxxx)
xxxxx2=[X for X in list(xxxxx) if (X >= xlow and X <= xmax)]
xxxx2=test[np.where(xxxxx == xxxxx2)]
    
test = np.array(yyyy)
yyyyy2=[Y for Y in list(yyyyy) if (Y >= ylow and Y <= ymax)]
yyyy2=test[np.where(yyyyy == yyyyy2)]

plt.xticks(xxxxx2,xxxx2)
plt.yticks(yyyyy2,yyyy2)
plt.tick_params(color='w', length=5)


plt.annotate('Region #1',xy=[(xmax1-xlow1)+xlow1-110,ymax1+1],\
            fontsize=8.0, horizontalalignment='center',verticalalignment='bottom', fontname = 'Times', color = 'w',fontweight='bold')
plt.annotate('Region #2',xy=[(xmax2-xlow2)+xlow2-110,ymax2+1],\
            fontsize=8.0, horizontalalignment='center',verticalalignment='bottom', fontname = 'Times', color = 'w',fontweight='bold')
plt.annotate('Region #3',xy=[(xmax3-xlow3)+xlow3-110,ymax3+1],\
            fontsize=8.0, horizontalalignment='center',verticalalignment='bottom', fontname = 'Times', color = 'w',fontweight='bold')
plt.annotate('Region #4',xy=[(xmax4-xlow4)+xlow4-110,ymax4+1],\
            fontsize=8.0, horizontalalignment='center',verticalalignment='bottom', fontname = 'Times', color = 'w',fontweight='bold')

# Plot the Ha Peaks Positions 
#plt.plot(regx, regy, '+w', markersize=5)

# Modification of the Plot area and the Axis Labels
plt.xlabel('$\mathrm{Right\,\,Ascension}$', fontsize=16, fontname='Helvetica')
plt.ylabel('$\mathrm{Declination}$', fontsize=16, fontname='Helvetica')
plt.subplots_adjust(top=0.99)
plt.subplots_adjust(bottom=0.1)
plt.subplots_adjust(left=-0.15)
plt.subplots_adjust(right=1.00)
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_6583_flux_reg.eps')
#plt.savefig('test.png', dpi=1000)
