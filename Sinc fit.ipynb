# %%
# Import Libraries
import matplotlib 
matplotlib.use('TkAgg')
from matplotlib import rc
import matplotlib.pyplot as plt
from astropy.io import fits
import numpy as np
from matplotlib.lines import Line2D
import pyfits as fits

# %%
sn1_s = fits.getdata('NGC628_SN1_1.0.SpectralCubeFitter.integrated_spectrum_0.fits')
sn1_f = fits.getdata('NGC628_SN1_1.0.SpectralCubeFitter.integrated_spectrum_fit_0.fits')
sn1_hh = fits.open('NGC628_SN1_1.0.SpectralCubeFitter.integrated_spectrum_0.fits')
sn1_h = sn1_hh[0].header
print sn1_h['CRVAL1']
print sn1_h['CD1_1']
print sn1_h['NAXIS1']

sn2_s = fits.getdata('NGC628_SN2_1.0.SpectralCubeFitter.integrated_spectrum_0.fits')
sn2_f = fits.getdata('NGC628_SN2_1.0.SpectralCubeFitter.integrated_spectrum_fit_0.fits')
sn2_hh = fits.open('NGC628_SN2_1.0.SpectralCubeFitter.integrated_spectrum_0.fits')
sn2_h = sn2_hh[0].header
print sn2_h['CRVAL1']
print sn2_h['CD1_1']
print sn2_h['NAXIS1']

sn3_s = fits.getdata('NGC628_SN3_1.0.SpectralCubeFitter.integrated_spectrum_0.fits')
sn3_f = fits.getdata('NGC628_SN3_1.0.SpectralCubeFitter.integrated_spectrum_fit_0.fits')
sn3_hh = fits.open('NGC628_SN3_1.0.SpectralCubeFitter.integrated_spectrum_0.fits')
sn3_h = sn3_hh[0].header
print sn3_h['CRVAL1']
print sn3_h['CD1_1']
print sn3_h['NAXIS1']
# Out:
# 345.982923079
# 0.411884432237
# 105
# 453.325839148
# 0.563838108393
# 134
# 617.77700687
# 0.239077789036
# 323

# %%
print len(sn1_s[0])
# Out:
# 105

# %%
# %matplotlib nbagg

plt.figure(figsize=(16,6))

plt.plot((sn1_h['CRVAL1']+(np.arange(sn1_h['NAXIS1']-57)+47)*sn1_h['CD1_1'])*10, sn1_s[0,47:95]/(1e-16), c='k', label='Spectrum')
plt.plot((sn1_h['CRVAL1']+(np.arange(sn1_h['NAXIS1']-57)+47)*sn1_h['CD1_1'])*10, sn1_f[0,47:95]/(1e-16), label='SN1 fit')
plt.xlim(3500,7000)

plt.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']-75)+50)*sn2_h['CD1_1'])*10, sn2_s[0,50:109]/(1e-16), c='k')
plt.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']-75)+50)*sn2_h['CD1_1'])*10, sn2_f[0,50:109]/(1e-16), label='SN2 fit')

plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_s[0,110:288]/(1e-16), c='k')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_f[0,110:288]/(1e-16), label='SN3 fit')
plt.ylim(-0.2,0.6)

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.08,0.75),fontsize=12)

plt.axvline(3738.5, color='k', linestyle='--')
plt.axvline(4869, color='k', linestyle='--')
plt.axvline(4968, color='k', linestyle='--')
plt.axvline(5017, color='k', linestyle='--')
plt.axvline(6562, color='k', linestyle='--')
plt.axvline(6578, color='k', linestyle='--')
plt.axvline(6597, color='k', linestyle='--')
plt.axvline(6692, color='k', linestyle='--')
plt.axvline(6731, color='k', linestyle='--')
plt.axvline(6745, color='k', linestyle='--')

plt.annotate('$\mathrm{[OII]\lambda3727}$',xy=(0.04,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{H}$'+r'$\beta$',xy=(0.38,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{[OIII]\lambda4959}$',xy=(0.41,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[OIII]\lambda5007}$',xy=(0.41,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{H}$'+r'$\alpha$',xy=(0.87,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{[NII]\lambda6548,6583}$',xy=(0.81,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{HeI\lambda6678}$',xy=(0.9,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[SII]\lambda6716,6731}$',xy=(0.91,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{\,SN3\,\,\,|\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,|  }$',xy=(0.795,0.24),xycoords='axes fraction',\
            fontsize=16.0, color='k')
plt.annotate('$\mathrm{R\,\,\simeq\,\,1800  }$',xy=(0.785,0.19),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{SN2\,\,\,|\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,|  }$',xy=(0.333,0.24),xycoords='axes fraction',\
            fontsize=16.0, color='k')
plt.annotate('$\mathrm{R\,\,\simeq\,\,600  }$',xy=(0.325,0.19),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{SN1\,|\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,|  }$',xy=(0.005,0.24),xycoords='axes fraction',\
            fontsize=16.0, color='k')
plt.annotate('$\mathrm{R\,\,\simeq\,\,600  }$',xy=(0.002,0.19),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_spectre_fit_regions.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
# %matplotlib nbagg


f,(ax,ax2,ax3) = plt.subplots(1,3,sharey=True, facecolor='w',figsize=(12,4))

x = np.arange(3500)+3500
# plot the same data on both axes

ax.set_xlim(3600,3900)
ax2.set_xlim(4800,5100)
ax3.set_xlim(6500,6800)

ax.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax.yaxis.tick_left()
ax.tick_params(labelright='off')
ax2.tick_params(labelleft='off')
ax2.tick_params(labelright='off')
ax3.yaxis.tick_right()
ax3.tick_params(labelleft='off')
ax.set_xticks(np.arange(4)*100+3600)
ax2.set_xticks(np.arange(4)*100+4800)
ax2.yaxis.set_ticks_position('none') 
ax3.set_xticks(np.arange(4)*100+6500)


ax.set_ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16)
ax2.set_xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

d = .01 # how big to make the diagonal lines in axes coordinates
# arguments to pass plot, just so we don't keep repeating them
kwargs = dict(transform=ax.transAxes, color='k', clip_on=False)
ax.plot((1-d,1+d), (-d,+d), **kwargs)
ax.plot((1-d,1+d),(1-d,1+d), **kwargs)

kwargs.update(transform=ax2.transAxes)  # switch to the bottom axes
ax2.plot((1-d,1+d), (-d,+d), **kwargs)
ax2.plot((1-d,1+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (1-d,1+d), **kwargs)
ax2.plot((-d,+d), (-d,+d), **kwargs)

kwargs.update(transform=ax3.transAxes)  # switch to the bottom axes
ax3.plot((-d,+d), (1-d,1+d), **kwargs)
ax3.plot((-d,+d), (-d,+d), **kwargs)


ax.plot((sn1_h['CRVAL1']+(np.arange(sn1_h['NAXIS1']-57)+47)*sn1_h['CD1_1'])*10, sn1_s[0,47:95]/(1e-16), c='k', label='Spectrum')
ax.plot((sn1_h['CRVAL1']+(np.arange(sn1_h['NAXIS1']-57)+47)*sn1_h['CD1_1'])*10, sn1_f[0,47:95]/(1e-16), label='SN1 fit')
ax.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']-75)+50)*sn2_h['CD1_1'])*10, sn2_f[0,50:109]/(1e-16), label='SN2 fit', c='g')
ax.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_f[0,110:288]/(1e-16), label='SN3 fit', c='r')
#ax.xlim(3500,7000)

ax2.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']-75)+50)*sn2_h['CD1_1'])*10, sn2_s[0,50:109]/(1e-16), c='k')
ax2.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']-75)+50)*sn2_h['CD1_1'])*10, sn2_f[0,50:109]/(1e-16), label='SN2 fit', c='g')



ax3.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_s[0,110:288]/(1e-16), c='k')
ax3.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_f[0,110:288]/(1e-16), label='SN3 fit', c='r')
plt.ylim(-0.2,0.5)

ax.legend(loc=(0.04,0.72),fontsize=8)

ax.axvline(3740.5, color='k', linestyle='--')
ax2.axvline(4870.8, color='k', linestyle='--')
ax2.axvline(4968.3, color='k', linestyle='--')
ax2.axvline(5017.3, color='k', linestyle='--')




ax.annotate('$\mathrm{[OII]\lambda3727}$',xy=(0.32,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

ax2.annotate('$\mathrm{H}$'+r'$\beta$',xy=(0.19,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

ax2.annotate('$\mathrm{[OIII]\lambda4959}$',xy=(0.47,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')
ax2.annotate('$\mathrm{[OIII]\lambda5007}$',xy=(0.47,1.01),xycoords='axes fraction',\
            fontsize=12.0, color='k')

ax3.annotate('$\mathrm{H}$'+r'$\alpha$',xy=(0.2,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')

ax3.annotate('$\mathrm{[NII]\lambda6548,6583}$',xy=(0.06,1.01),xycoords='axes fraction',\
            fontsize=12.0, color='k')

ax3.annotate('$\mathrm{HeI\lambda6678}$',xy=(0.52,1.05),xycoords='axes fraction',\
         fontsize=12.0, color='k')
ax3.annotate('$\mathrm{[SII]\lambda6716,6731}$',xy=(0.6,1.01),xycoords='axes fraction',\
         fontsize=12.0, color='k')
#ax3.annotate('$\mathrm{\,SN3\,\,\,|\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,|  }$',xy=(0.795,0.24),xycoords='axes fraction',\
#         fontsize=16.0, color='k')
ax3.annotate('$\mathrm{R\,\,\simeq\,\,1800  }$',xy=(0.35,0.40),xycoords='axes fraction',\
         fontsize=12.0, color='k')
#ax2.annotate('$\mathrm{SN2\,\,\,|\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,|  }$',xy=(0.333,0.24),xycoords='axes fraction',\
#         fontsize=16.0, color='k')
ax.annotate('$\mathrm{R\,\,\simeq\,\,600  }$',xy=(0.18,0.40),xycoords='axes fraction',\
         fontsize=12.0, color='k')
#ax.annotate('$\mathrm{SN1\,|\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,\,|  }$',xy=(0.005,0.24),xycoords='axes fraction',\
#         fontsize=16.0, color='k')
ax2.annotate('$\mathrm{R\,\,\simeq\,\,600  }$',xy=(0.28,0.40),xycoords='axes fraction',\
            fontsize=12.0, color='k')
ax3.axvline(6564.5, color='k', linestyle='--')
ax3.axvline(6579, color='k', linestyle='--')
ax3.axvline(6599.5, color='k', linestyle='--')
ax3.axvline(6694, color='k', linestyle='--')
ax3.axvline(6732.5, color='k', linestyle='--')
ax3.axvline(6747, color='k', linestyle='--')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_spectre_fit_regions.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
# %matplotlib nbagg

plt.xlim(6480,6840)

plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_s[0,110:288]/(1e-16), c='k', label='Spectrum')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_f[0,110:288]/(1e-16),c='r',  label='SN3 fit')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, (sn3_s[0,110:288]/(1e-16)-sn3_f[0,110:288]/(1e-16))-0.5,c='grey',  label='Residual')
plt.ylim(-0.6,1.5)

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16,)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.755,0.8),fontsize=12)

plt.axvline(6564, color='k', linestyle='--')
plt.axvline(6579, color='k', linestyle='--')
plt.axvline(6599, color='k', linestyle='--')
plt.axvline(6694, color='k', linestyle='--')
plt.axvline(6732.5, color='k', linestyle='--')
plt.axvline(6747, color='k', linestyle='--')


plt.annotate('$\mathrm{H}$'+r'$\alpha$',xy=(0.255,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{[NII]\lambda6548}$',xy=(0.16,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[NII]\lambda6548}$',xy=(0.29,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{HeI\lambda6678}$',xy=(0.53,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[SII]\lambda6716}$',xy=(0.605,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[SII]\lambda6731}$',xy=(0.73,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('c',xy=(0.05,0.9),xycoords='axes fraction',\
            fontsize=20.0, color='k')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_spectre_fit_sn3.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
# %matplotlib nbagg

plt.xlim(4801,5149)

plt.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']-75)+50)*sn2_h['CD1_1'])*10, sn2_s[0,50:109]/(1e-16), c='k', label='Spectrum')
plt.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']-75)+50)*sn2_h['CD1_1'])*10, sn2_f[0,50:109]/(1e-16), c='g',label='SN2 fit')
plt.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']-75)+50)*sn2_h['CD1_1'])*10, (sn2_s[0,50:109]/(1e-16)-sn2_f[0,50:109]/(1e-16))-0.1, c='grey', label='Residual')
plt.ylim(-0.2,0.2)
plt.yticks([-0.2,-0.1,0.,0.1,0.2])

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16,)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.74,0.8),fontsize=12)

plt.axvline(4872, color='k', linestyle='--')
plt.axvline(4969, color='k', linestyle='--')
plt.axvline(5018, color='k', linestyle='--')

plt.annotate('$\mathrm{H}$'+r'$\beta$',xy=(0.19,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{[OIII]\lambda4959}$',xy=(0.405,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[OIII]\lambda5007}$',xy=(0.555,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('b',xy=(0.05,0.9),xycoords='axes fraction',\
            fontsize=20.0, color='k')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_spectre_fit_sn2.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
# %matplotlib nbagg


plt.plot((sn1_h['CRVAL1']+(np.arange(sn1_h['NAXIS1']-58)+48)*sn1_h['CD1_1'])*10, sn1_s[0,48:95]/(1e-16), c='k', label='Spectrum')
plt.plot((sn1_h['CRVAL1']+(np.arange(sn1_h['NAXIS1']-58)+48)*sn1_h['CD1_1'])*10, sn1_f[0,48:95]/(1e-16), label='SN1 fit')
plt.plot((sn1_h['CRVAL1']+(np.arange(sn1_h['NAXIS1']-58)+48)*sn1_h['CD1_1'])*10, (sn1_s[0,48:95]/(1e-16)-sn1_f[0,48:95]/(1e-16))-0.1, c='grey', label='Residual')
plt.ylim(-0.2,0.6)

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16,)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.74,0.8),fontsize=12)

plt.axvline(3740.3, color='k', linestyle='--')

plt.annotate('$\mathrm{[OII]\lambda3727}$',xy=(0.38,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.xlim(3651,3849)

plt.annotate('a',xy=(0.05,0.9),xycoords='axes fraction',\
            fontsize=20.0, color='k')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_spectre_fit_sn1.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
sn1_sp = fits.getdata('NGC628_SN1_sp.fits')

sn2_sp = fits.getdata('NGC628_SN2_sp.fits')

sn3_sp = fits.getdata('NGC628_SN3_sp.fits')
sn3_sp2 = fits.getdata('NGC628_SN3_1.0.SpectralCubeFitter.integrated_spectrum_0_center.fits')
sn3_sp3 = fits.getdata('NGC628_SN3_1.0.SpectralCubeFitter.integrated_spectrum_0_center2.fits')

sp = fits.getdata('NGC628_SN3_1.0.SpectralCubeFitter.integrated_spectrum_0_old_pixel3.fits')
sp_dig = fits.getdata('NGC628_SN3_1.0.SpectralCubeFitter.integrated_spectrum_0_DIG.fits')
sp2 = fits.getdata('test7.fits')
sp_sky = fits.getdata('NGC628_SN3_1.0.SpectralCubeFitter.integrated_spectrum_0_sky.fits')


print len(sn1_sp)
print len(sn2_sp)
print len(sn3_sp)
# Out:
# 105
# 134
# 323

# %%
# %matplotlib nbagg

plt.xlim(6480,6840)

plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sp[0,110:288]/(1e-16), c='k', label='Spectrum')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_sp[110:288]/(1.8e-16),c='r',  label='Continuum')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sp[0,110:288]/(1e-16)-sn3_sp[110:288]/(1.8e-16)-0.1,c='grey',  label='Final')
plt.ylim(-0.15,0.17)

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16,)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.745,0.82),fontsize=12)

plt.axvline(6511, color='k', linestyle='--')
plt.axvline(6564, color='k', linestyle='--')
plt.axvline(6578, color='k', linestyle='--')
plt.axvline(6599, color='k', linestyle='--')
plt.axvline(6732.5, color='k', linestyle='--')
plt.axvline(6747, color='k', linestyle='--')


plt.annotate('$\mathrm{FeI\lambda6495}$',xy=(0.04,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{H}$'+r'$\alpha$',xy=(0.255,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{[NII]\lambda6548}$',xy=(0.16,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[NII]\lambda6548}$',xy=(0.29,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{[SII]\lambda6716}$',xy=(0.605,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[SII]\lambda6731}$',xy=(0.73,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('b',xy=(0.05,0.9),xycoords='axes fraction',\
            fontsize=20.0, color='k')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_spectre_cont_pixel2_sn3.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
# %matplotlib nbagg

plt.xlim(6480,6840)

plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sp_dig[0,110:288]/(1e-16), c='k', label='Spectrum')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_sp[110:288]/(7e-16),c='r',  label='Continuum')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sp_dig[0,110:288]/(1e-16)-sn3_sp[110:288]/(7e-16),c='grey',  label='Final')
plt.ylim(-0.005,0.025)

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16,)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.745,0.82),fontsize=12)

plt.axvline(6511, color='k', linestyle='--')
plt.axvline(6564, color='k', linestyle='--')
plt.axvline(6578, color='k', linestyle='--')
plt.axvline(6599, color='k', linestyle='--')
plt.axvline(6732.5, color='k', linestyle='--')
plt.axvline(6747, color='k', linestyle='--')


plt.annotate('$\mathrm{FeI\lambda6495}$',xy=(0.04,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{H}$'+r'$\alpha$',xy=(0.255,1.05),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{[NII]\lambda6548}$',xy=(0.16,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[NII]\lambda6548}$',xy=(0.29,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{[SII]\lambda6716}$',xy=(0.605,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('$\mathrm{[SII]\lambda6731}$',xy=(0.73,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_spectre_cont_dig_sn3.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
# %matplotlib nbagg

plt.xlim(4800,5145)

plt.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']))*sn2_h['CD1_1'])*10, sp2[0:]/(1e-16)+sn2_sp[0:]/(1.8e-16), c='k', label='Spectrum')
plt.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']))*sn2_h['CD1_1'])*10, sn2_sp[0:]/(1.8e-16),c='g',  label='Continuum')
plt.plot((sn2_h['CRVAL1']+(np.arange(sn2_h['NAXIS1']))*sn2_h['CD1_1'])*10, sp2[0:]/(1e-16),c='grey',  label='Final')
plt.ylim(-0.022,0.09)

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16,)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.745,0.82),fontsize=12)

plt.axvline(4870.8, color='k', linestyle='--')



plt.annotate('$\mathrm{H}$'+r'$\beta$',xy=(0.185,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')
plt.annotate('a',xy=(0.05,0.9),xycoords='axes fraction',\
            fontsize=20.0, color='k')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_spectre_cont_pixel2_sn2.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
# %matplotlib nbagg

plt.xlim(6480,6840)

#plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_sp2[0,110:288]/(1e-16),c='k',  label='Continuum')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_sp3[0,110:288],c='k')
#plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, (sp[0,110:288]/(1e-16)-sn3_sp[110:288]/(1e-16))-0.3,c='grey',  label='Residual')
plt.ylim(0,0.2)

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16,)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.745,0.85),fontsize=12)

plt.axvline(6511, color='k', linestyle='--')
plt.axvline(6579, color='k', linestyle='--')



plt.annotate('$\mathrm{FeI\lambda6495}$',xy=(0.04,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')

plt.annotate('$\mathrm{H}$'+r'$\alpha$',xy=(0.255,1.02),xycoords='axes fraction',\
            fontsize=12.0, color='k')


plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_cont_sn3.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)

# %%
# %matplotlib nbagg

plt.xlim(6480,6850)

#plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, sn3_sp2[0,110:288]/(1e-16),c='k',  label='Continuum')
plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-120)+110)*sn3_h['CD1_1'])*10-2, sp_sky[0,110:313]/(1e-16),c='k')
#plt.plot((sn3_h['CRVAL1']+(np.arange(sn3_h['NAXIS1']-145)+110)*sn3_h['CD1_1'])*10, (sp[0,110:288]/(1e-16)-sn3_sp[110:288]/(1e-16))-0.3,c='grey',  label='Residual')
plt.ylim(-0.005,0.035)

plt.ylabel('$\mathrm{Flux\,\,[10^{-16}\,\,erg\,\,s^{-1}\,\,cm^{-2}\,\,\AA^{-1}]}$', fontname='Helvetica',fontsize=16,)
plt.xlabel('$\mathrm{Wavelength\,\,[\AA]}$', fontname='Helvetica',fontsize=16)

plt.legend(loc=(0.745,0.85),fontsize=12)

plt.axvline(6498.7, color='k', linestyle='--')
plt.axvline(6505, color='k', linestyle='--')
plt.axvline(6522.4, color='k', linestyle='--')
plt.axvline(6533, color='k', linestyle='--')
plt.axvline(6544, color='k', linestyle='--')
plt.axvline(6553.6, color='k', linestyle='--')
plt.axvline(6562.8, color='k', linestyle='--')
plt.axvline(6568.8, color='k', linestyle='--')
plt.axvline(6583.4, color='k', linestyle='--')
plt.axvline(6604, color='k', linestyle='--')
plt.axvline(6627.6, color='k', linestyle='--')
plt.axvline(6634.2, color='k', linestyle='--')
plt.axvline(6667.6, color='k', linestyle='--')
plt.axvline(6699.6, color='k', linestyle='--')
plt.axvline(6704.7, color='k', linestyle='--')
plt.axvline(6744.9, color='k', linestyle='--')
plt.axvline(6744.9, color='k', linestyle='--')
plt.axvline(6834.0, color='k', linestyle='--')
plt.axvline(6828, color='k', linestyle='--')
plt.axvline(6841.9, color='k', linestyle='--')

plt.axvline(6577, color='k', linestyle='--')
plt.axvline(6597, color='k', linestyle='--')


plt.annotate('$\mathrm{6\minus1\,\,Q2}$',xy=(0.035,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,Q1}$',xy=(0.06,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P2}$',xy=(0.105,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P1}$',xy=(0.135,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P2}$',xy=(0.165,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P1}$',xy=(0.19,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{H}$'+r'$\alpha$',xy=(0.213,1.03),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P1}$',xy=(0.233,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{[NII]}$',xy=(0.275,1.045),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{H}$'+r'$\alpha\,gal$',xy=(0.253,1.075),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{[NII]}\,gal$',xy=(0.305,1.085),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P1}$',xy=(0.33,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P2}$',xy=(0.39,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P1}$',xy=(0.41,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P1}$',xy=(0.495,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P2}$',xy=(0.58,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P1}$',xy=(0.6,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{6\minus1\,\,P1}$',xy=(0.705,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{7\minus2\,\,R2}$',xy=(0.93,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{7\minus2\,\,R2}$',xy=(0.95,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.annotate('$\mathrm{7\minus2\,\,R2}$',xy=(0.97,1.08),xycoords='axes fraction',\
            fontsize=10.0, color='k', rotation = 90)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#Save the Plot in a .eps or .png file
plt.savefig('NGC628_sky_sn3.eps', transparent=True, bbox_inches='tight', pad_inches=0.04)
#plt.savefig('NGC628_flux_reg_GROW5.eps')
#plt.savefig('test.png', dpi=1000)
